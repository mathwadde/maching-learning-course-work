# %% [markdown]
# <a href="https://colab.research.google.com/github/mathwadde/maching-learning-course-work/blob/main/Copy_of_class_work1_(simple_linear_regression_model)_on_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# Upload file
uploaded = files.upload()

# Read the CSV file into a pandas DataFrame
import io
df = pd.read_csv(io.BytesIO(list(uploaded.values())[0]))

# Display the  rows
df
# Out:
#      <input type="file" id="files-10ff5bfd-1429-4a3a-add7-90aea1d58ec3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10ff5bfd-1429-4a3a-add7-90aea1d58ec3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Remove spaces before/after column names
df.columns = df.columns.str.strip()

# Rename
df.rename(columns={'Traffic Density': 'Density', 'Air Pollution': 'Pollution'}, inplace=True)

# Check result
print(df.columns.tolist())
# Out:
# ['Days', 'Density', 'Pollution']

# %%
df
# Out:
#    Days  Density  Pollution
# 0     1     1000         30
# 1     2     1200         35
# 2     3     1500         42
# 3     4      800         25
# 4     5     1700         48
# 5     6      900         28
# 6     7     1400         40
# 7     8     2000         55
# 8     9     1100         33
# 9    10     1800         50

# %%
x= df['Density']
y=df['Pollution']

# %%
    pd.DataFrame(pearsonr(x,y,index=['pearson_coff', 'p_value'], columns = ['Density', 'Pollution']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-544813802.py in <cell line: 0>()
# ----> 1 pd.DataFrame(pearsonr(x,y,index=['pearson_coff', 'p_value'], columns = ['Density', 'Pollution']))
#       2
#
# TypeError: pearsonr() got an unexpected keyword argument 'index'

# %%
# Compute the correlation_coefficient
Person_corr, p_value = pearsonr(x, y)

# Create DataFrame
df_corr = pd.DataFrame({
    'Density': [corr],
    'Pollution': [p_value]
}, index=['pearson_coff'])

print(df_corr)
# Out:
#               Density     Pollution
# pearson_coff  0.99953  2.133383e-13

# %%
plt.scatter(x, y)
plt.title('Density vs Pollution')
plt.xlabel('Density')
plt.ylabel('Pollution')
plt.show()

# %%
stats.linregress(x, y)
# Out:
# LinregressResult(slope=np.float64(0.024838274932614555), intercept=np.float64(5.316711590296499), rvalue=np.float64(0.9995300150569526), pvalue=np.float64(2.1333832477996495e-13), stderr=np.float64(0.0002693311171389414), intercept_stderr=np.float64(0.37552137526604124))

# %%
# Fit linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# Define prediction function
def pred(x):
    return slope * x + intercept

fitline = pred(x)

# %%
print(pred(2800))
# Out:
# 74.86388140161725

# %%
print(pred(5000))
# Out:
# 129.50808625336927
